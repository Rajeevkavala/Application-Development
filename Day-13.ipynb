# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\rajee\Downloads\result.csv")
df
# Out:
#                     Id  Success  Created  Error
# 0   003Qy00000EjWVqIAN     True     True    NaN
# 1   003Qy00000EjWVrIAN     True     True    NaN
# 2   003Qy00000EjWVsIAN     True     True    NaN
# 3   003Qy00000EjWVtIAN     True     True    NaN
# 4   003Qy00000EjWVuIAN     True     True    NaN
# 5   003Qy00000EjWVvIAN     True     True    NaN
# 6   003Qy00000EjWVwIAN     True     True    NaN
# 7   003Qy00000EjWVxIAN     True     True    NaN
# 8   003Qy00000EjWVyIAN     True     True    NaN
# 9   003Qy00000EjWVzIAN     True     True    NaN
# 10  003Qy00000EjWW0IAN     True     True    NaN
# 11  003Qy00000EjWW1IAN     True     True    NaN
# 12  003Qy00000EjWW2IAN     True     True    NaN
# 13  003Qy00000EjWW3IAN     True     True    NaN
# 14  003Qy00000EjWW4IAN     True     True    NaN
# 15  003Qy00000EjWW5IAN     True     True    NaN
# 16  003Qy00000EjWW6IAN     True     True    NaN
# 17  003Qy00000EjWW7IAN     True     True    NaN
# 18  003Qy00000EjWW8IAN     True     True    NaN
# 19  003Qy00000EjWW9IAN     True     True    NaN

# %%
taxi_df=sns.load_dataset('taxis')
taxi_df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %%
sns.barplot(x='payment',y='total',data=taxi_df,color='red',estimator='std')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=taxi_df['fare'],color='blue')
plt.show()

# %%
sns.histplot(x=taxi_df['fare'],palette=['blue','red'],hue=taxi_df['payment'])
plt.show()

# %%
sns.histplot(x=taxi_df['fare'],palette=['g','y'],hue=taxi_df['payment'])
plt.show()

# %%
sns.distplot(x=taxi_df['fare'],hist=True,kde=False)
plt.show()

# %%
sns.distplot(x=taxi_df['fare'],hist=False,kde=True)
plt.show()

# %%
sns.distplot(x=taxi_df['fare'],hist=True,kde=True)
plt.show()

# %%
sns.boxplot(x=taxi_df['fare'],color='red')
plt.show()

# %%
iris_data = sns.load_dataset('iris')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=iris_data['petal_length'],color='violet')
plt.show()
