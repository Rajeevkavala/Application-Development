# %% [markdown]
# # Data Analysis and Machine Learning Workflow
#
# ## 1) Problem Statement
# - Define the problem you are trying to solve with the dataset.
#
# ## 2) Talk About Columns
# - Describe the dataset columns, their meanings, and data types.
#
# ## 3) Install the Modules and Required Libraries
# - Install necessary Python libraries (e.g., `pandas`, `numpy`, `sklearn`, `matplotlib`, `seaborn`).
#
# ## 4) Load Dataset
# - Load the dataset into a pandas DataFrame.
#
# ## 5) Understand Your Data
# - Explore basic info:
#   - `shape`
#   - `info()`
#   - `describe()`
#   - `head()`
#
# ## 6) Exploratory Data Analysis (EDA)
# ### i) Univariate Analysis
# - Analyze individual columns (e.g., histograms, count plots).
# ### ii) Bivariate Analysis
# - Explore relationships between two variables (e.g., scatter plots, correlation).
# ### iii) Multivariate Analysis
# - Analyze interactions among multiple variables (e.g., pair plots, heatmaps).
#
# ## 7) Check Null Values or Missing Values
# ### i) Treating the Null Values
# - Fill with mean, median, or mode based on the column distribution.
# ### ii) Drop Null Values
# - Drop rows/columns if null values are less than 5%-10% of the dataset.
#
# ## 8) Check Duplicates
# ### i) Drop Duplicates
# - Identify and remove duplicate rows.
#
# ## 9) Treating Outliers
# ### i) Check the Outliers
# - Use statistical methods (e.g., IQR) or visualizations (e.g., box plots).
# ### ii) Remove Outliers
# - Remove outliers based on defined thresholds.
# ### iii) Make Box Plots
# - Create box plots before and after outlier removal for comparison.
#
# ## 10) Feature Engineering
# ### a) Feature Extraction, Creation, and Selection
# #### i) Extract Features
# - Extract meaningful information from existing columns.
# #### ii) Create Features
# - Create new features based on domain knowledge.
# #### iii) Select Features
# - Select relevant features for modeling.
# ### b) Checking Multicollinearity
# #### i) Heatmap
# - Visualize correlation between features using a heatmap.
# #### ii) VIF Technique
# - Calculate Variance Inflation Factor (VIF) to detect multicollinearity.
# ### c) Transformation
# #### i) One-Hot Encoding or Label Encoding
# - Convert categorical variables into numerical format.
# ### d) Scaling
# - Apply Min-Max Scaler or Standard Scaler to normalize features.
#
# ## 11) X-y Features Split
# - Split the dataset into independent (`X`) and dependent (`y`) variables.
#
# ## 12) Train-Test Split
# - Split the data into training and testing sets (e.g., 80-20 split).
#
# ## For Classification
# ### 1) Apply SMOTE Technique
# - Handle imbalanced datasets using the Synthetic Minority Over-sampling Technique (SMOTE).
# ### 2) Build the Models
# - Implement different classification models:
#   - i) Logistic Regression
#   - ii) Decision Tree
#   - iii) Random Forest
#   - iv) Gradient Boost
#   - v) AdaBoost
#   - vi) K-Nearest Neighbors (KNN)
#   - vii) Support Vector Machine (SVM)
#   - viii) Naïve Bayes
# ### 3) Hyperparameter Tuning
# #### i) Cross Validation
# - Perform cross-validation to improve model generalization and performance.
# ### 4) Deploy the best model in streamlit or flask
#
# ## For Regression
# ### 1) Apply the models
# - i) Linear regression
# - ii) Decision Tree
# - iii) Random Forest
# - iv) Gradient Boost
# - v) KNN
# - vi) SVM
# ### 2) Hyperparameter Tuning
# #### i) Cross Validation
# - Perform cross-validation to improve model generalization and performance.
# ### 3) Deploy the best model in streamlit or flask
#
# ## For Regression
# ### 1)Apply the models
# - i) k-means
# - ii) DBSCAN
# - iii) Hierachical
# ### 2) Deploy the best model in streamlit or flask

# %% [markdown]
# # Data Collection

# %% [markdown]
# ### Importing Required Libraries
# ### `pandas`: For data manipulation and analysis.
# ### `numpy`: For numerical computations.
# ### `matplotlib.pyplot` & `seaborn`: For data visualization.
# ### `sklearn.preprocessing.StandardScaler`: To standardize features for consistent scaling.
# ### `sklearn.neighbors.NearestNeighbors`: To find similar songs based on feature distances.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
# Here we are loading the dataset
df = pd.read_csv(r"C:\Users\rajee\Downloads\archive\data\data.csv")

# %% [markdown]
# ### Loading the Dataset
# ### - Loads the Spotify dataset from a CSV file (`data.csv`).
# ### - File path: Specific to the user's local system.
# ### - Contains 170,653 songs with 19 features like valence, danceability, etc.

# %%
df
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# 170648  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...         0.786
# 170649                                       ['Ashnikko']         0.717
# 170650                                        ['MAMAMOO']         0.634
# 170651                                         ['Eminem']         0.671
# 170652                              ['KEVVO', 'J Balvin']         0.856
#
#         duration_ms  energy  explicit                      id  \
# 0            831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 1            180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 2            500062   0.166         0  1o6I8BglA6ylDMrIELygv1
# 3            210000   0.309         0  3ftBPsC5vPBKxYSee08FDH
# 4            166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
# ...             ...     ...       ...                     ...
# 170648       301714   0.808         0  0KkIkfsLEJbrcIhYsCL7L5
# 170649       150654   0.753         0  0OStKKAuXlxA0fMH54Qs6E
# 170650       211280   0.858         0  4BZXVFYCb76Q0Klojq4piV
# 170651       337147   0.623         1  5SiZJoLXp3WOl3J4C8IK0d
# 170652       189507   0.721         1  7HmnJHfs0BkFzX4x8j0hkl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.878000   10    0.6650   -20.096     1
# 1               0.000000    7    0.1600   -12.441     1
# 2               0.913000    3    0.1010   -14.850     1
# 3               0.000028    5    0.3810    -9.316     1
# 4               0.000002    3    0.2290   -10.096     1
# ...                  ...  ...       ...       ...   ...
# 170648          0.000289    7    0.0822    -3.702     1
# 170649          0.000000    7    0.1010    -6.020     1
# 170650          0.000009    4    0.2580    -2.226     0
# 170651          0.000008    2    0.6430    -7.161     1
# 170652          0.004710    7    0.1820    -4.928     1
#
#                                                      name  popularity  \
# 0       Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1                                 Clancy Lowered the Boom           5
# 2                                               Gati Bali           5
# 3                                               Danny Boy           3
# 4                             When Irish Eyes Are Smiling           2
# ...                                                   ...         ...
# 170648                                              China          72
# 170649                        Halloweenie III: Seven Days          68
# 170650                                                AYA          76
# 170651                                           Darkness          70
# 170652                    Billetes Azules (with J Balvin)          74
#
#        release_date  speechiness    tempo
# 0              1921       0.0366   80.954
# 1              1921       0.4150   60.936
# 2              1921       0.0339  110.339
# 3              1921       0.0354  100.109
# 4              1921       0.0380  101.665
# ...             ...          ...      ...
# 170648   2020-05-29       0.0881  105.029
# 170649   2020-10-23       0.0605  137.936
# 170650   2020-11-03       0.0809   91.688
# 170651   2020-01-17       0.3080   75.055
# 170652   2020-10-16       0.1080   94.991
#
# [170653 rows x 19 columns]

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
df.shape
# Out:
# (170653, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
#  16  release_date      170653 non-null  object
#  17  speechiness       170653 non-null  float64
#  18  tempo             170653 non-null  float64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.7+ MB

# %%
categorical_cols = ['artists','id','name','release_date']
categorical_data = []
for i in categorical_cols:
    print(f"Column:{i}")
    categorical_data = df[i].head()
    print(categorical_data)
    print("\n")
# Out:
# Column:artists
# 0    ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 1                                       ['Dennis Day']
# 2    ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 3                                     ['Frank Parker']
# 4                                       ['Phil Regan']
# Name: artists, dtype: object
#
#
# Column:id
# 0    4BJqT0PrAfrxzMOxytFOIz
# 1    7xPhfUan2yNtyFG0cUWkt8
# 2    1o6I8BglA6ylDMrIELygv1
# 3    3ftBPsC5vPBKxYSee08FDH
# 4    4d6HGyGT8e121BsdKmw9v6
# Name: id, dtype: object
#
#
# Column:name
# 0    Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1                              Clancy Lowered the Boom
# 2                                            Gati Bali
# 3                                            Danny Boy
# 4                          When Irish Eyes Are Smiling
# Name: name, dtype: object
#
#
# Column:release_date
# 0    1921
# 1    1921
# 2    1921
# 3    1921
# 4    1921
# Name: release_date, dtype: object

# %%
for col in categorical_cols:
    top_10 = df[col].value_counts().nlargest(10)
    plt.figure(figsize=(10, 6)) 
    sns.barplot(x=top_10.values, y=top_10.index, orient='h')
    plt.title(f'Top 10 Distribution of {col}')
    plt.xlabel('Count')
    plt.ylabel(col)
    plt.show()

# %%
df.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# 25%    1.698270e+05       0.255000       0.000000          0.000000
# 50%    2.074670e+05       0.471000       0.000000          0.000216
# 75%    2.624000e+05       0.703000       0.000000          0.102000
# max    5.403500e+06       1.000000       1.000000          1.000000
#
#                  key       liveness       loudness           mode  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        5.199844       0.205839     -11.467990       0.706902
# std         3.515094       0.174805       5.697943       0.455184
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         2.000000       0.098800     -14.615000       0.000000
# 50%         5.000000       0.136000     -10.580000       1.000000
# 75%         8.000000       0.261000      -7.183000       1.000000
# max        11.000000       1.000000       3.855000       1.000000
#
#           popularity    speechiness          tempo
# count  170653.000000  170653.000000  170653.000000
# mean       31.431794       0.098393     116.861590
# std        21.826615       0.162740      30.708533
# min         0.000000       0.000000       0.000000
# 25%        11.000000       0.034900      93.421000
# 50%        33.000000       0.045000     114.729000
# 75%        48.000000       0.075600     135.537000
# max       100.000000       0.970000     243.507000

# %%
df.isnull().sum()
# Out:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %%
# Here we a taking a simple of 5000 rows for analysis
# df = df.sample(n=5000, random_state=42).reset_index(drop=True)

# %%
df
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# 170648  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...         0.786
# 170649                                       ['Ashnikko']         0.717
# 170650                                        ['MAMAMOO']         0.634
# 170651                                         ['Eminem']         0.671
# 170652                              ['KEVVO', 'J Balvin']         0.856
#
#         duration_ms  energy  explicit                      id  \
# 0            831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 1            180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 2            500062   0.166         0  1o6I8BglA6ylDMrIELygv1
# 3            210000   0.309         0  3ftBPsC5vPBKxYSee08FDH
# 4            166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
# ...             ...     ...       ...                     ...
# 170648       301714   0.808         0  0KkIkfsLEJbrcIhYsCL7L5
# 170649       150654   0.753         0  0OStKKAuXlxA0fMH54Qs6E
# 170650       211280   0.858         0  4BZXVFYCb76Q0Klojq4piV
# 170651       337147   0.623         1  5SiZJoLXp3WOl3J4C8IK0d
# 170652       189507   0.721         1  7HmnJHfs0BkFzX4x8j0hkl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.878000   10    0.6650   -20.096     1
# 1               0.000000    7    0.1600   -12.441     1
# 2               0.913000    3    0.1010   -14.850     1
# 3               0.000028    5    0.3810    -9.316     1
# 4               0.000002    3    0.2290   -10.096     1
# ...                  ...  ...       ...       ...   ...
# 170648          0.000289    7    0.0822    -3.702     1
# 170649          0.000000    7    0.1010    -6.020     1
# 170650          0.000009    4    0.2580    -2.226     0
# 170651          0.000008    2    0.6430    -7.161     1
# 170652          0.004710    7    0.1820    -4.928     1
#
#                                                      name  popularity  \
# 0       Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1                                 Clancy Lowered the Boom           5
# 2                                               Gati Bali           5
# 3                                               Danny Boy           3
# 4                             When Irish Eyes Are Smiling           2
# ...                                                   ...         ...
# 170648                                              China          72
# 170649                        Halloweenie III: Seven Days          68
# 170650                                                AYA          76
# 170651                                           Darkness          70
# 170652                    Billetes Azules (with J Balvin)          74
#
#        release_date  speechiness    tempo
# 0              1921       0.0366   80.954
# 1              1921       0.4150   60.936
# 2              1921       0.0339  110.339
# 3              1921       0.0354  100.109
# 4              1921       0.0380  101.665
# ...             ...          ...      ...
# 170648   2020-05-29       0.0881  105.029
# 170649   2020-10-23       0.0605  137.936
# 170650   2020-11-03       0.0809   91.688
# 170651   2020-01-17       0.3080   75.055
# 170652   2020-10-16       0.1080   94.991
#
# [170653 rows x 19 columns]

# %%
df.shape
# Out:
# (170653, 19)

# %%
print(f"Total tracks in sample: {len(df)}")
print(f"Columns available: {(df.columns.tolist())}")
# Out:
# Total tracks in sample: 170653
# Columns available: ['valence', 'year', 'acousticness', 'artists', 'danceability', 'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo']

# %% [markdown]
# # Data Pre-Processing

# %%
# Here we a categorizing the track based on the 
# Features like acousticness,speechiness,etc
relaxation_category = (df["acousticness"] > 0.7) & (df["energy"] < 0.5) & (df["tempo"]>60) & (df["tempo"]<120)
devotional_category = (df["speechiness"] > 0.4) & (df["instrumentalness"] > 0.3)
other_category = ~(relaxation_category | devotional_category)

# %%
# Here we are adding new columns for Relaxation/Yoga,Devotional,Other
df.loc[relaxation_category, "category"] = "Relaxation/Yoga"
df.loc[devotional_category, "category"] = "Devotional"
df.loc[other_category, "category"] = "Other"

# %%
# Here we are showing the columns
print("\nCategories:")
df["category"]
# Out:
# Categories:
# 0         Relaxation/Yoga
# 1         Relaxation/Yoga
# 2         Relaxation/Yoga
# 3         Relaxation/Yoga
# 4         Relaxation/Yoga
#                ...
# 170648              Other
# 170649              Other
# 170650              Other
# 170651              Other
# 170652              Other
# Name: category, Length: 170653, dtype: object

# %% [markdown]
# ## Visualization of the No.of Tracks in the Dataset

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="category", data=df)
plt.title("Count of Tracks by Category")
plt.xlabel("Category")
plt.ylabel("Number of Tracks")

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
#  16  release_date      170653 non-null  object
#  17  speechiness       170653 non-null  float64
#  18  tempo             170653 non-null  float64
#  19  category          170653 non-null  object
# dtypes: float64(9), int64(6), object(5)
# memory usage: 26.0+ MB

# %% [markdown]
# # Here we are Filting data that has relaxation and devotional songs

# %%
df_filtered = df[df["category"] != "Other"].reset_index(drop=True)
print(f"\nFiltered dataset contains {len(df_filtered)} tracks that are yoga and devotional.")
# Out:
# Filtered dataset contains 40434 tracks that are yoga and devotional.

# %%
df_filtered
# Out:
#        valence  year  acousticness  \
# 0       0.0594  1921         0.982
# 1       0.9630  1921         0.732
# 2       0.0394  1921         0.961
# 3       0.1650  1921         0.967
# 4       0.2530  1921         0.957
# ...        ...   ...           ...
# 40429   0.3520  2020         0.951
# 40430   0.3620  2020         0.719
# 40431   0.3520  2020         0.886
# 40432   0.1690  2020         0.994
# 40433   0.0838  2020         0.974
#
#                                                  artists  danceability  \
# 0      ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                         ['Dennis Day']         0.819
# 2      ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                       ['Frank Parker']         0.275
# 4                                         ['Phil Regan']         0.418
# ...                                                  ...           ...
# 40429                                   ['Anson Seabra']         0.691
# 40430                                     ['Dan + Shay']         0.420
# 40431                                     ['Tate McRae']         0.569
# 40432                                 ['Ólafur Arnalds']         0.281
# 40433                                   ['Najma Wallin']         0.175
#
#        duration_ms   energy  explicit                      id  \
# 0           831667  0.21100         0  4BJqT0PrAfrxzMOxytFOIz
# 1           180533  0.34100         0  7xPhfUan2yNtyFG0cUWkt8
# 2           500062  0.16600         0  1o6I8BglA6ylDMrIELygv1
# 3           210000  0.30900         0  3ftBPsC5vPBKxYSee08FDH
# 4           166693  0.19300         0  4d6HGyGT8e121BsdKmw9v6
# ...            ...      ...       ...                     ...
# 40429       222468  0.06820         0  6hjh2phISvfR1Ib6S0FK7b
# 40430       195067  0.46600         0  6DeGFcrDiYDuyV7e7KnqPd
# 40431       190652  0.27100         0  2GSLoT7abyYGchSSDCpWEI
# 40432       190500  0.03330         0  13MOQ6oQqkrZEDkZOHukCw
# 40433       133500  0.00759         0  6RuFOroO9VO0aMGEzirLHk
#
#        instrumentalness  key  liveness  loudness  mode  \
# 0              0.878000   10    0.6650   -20.096     1
# 1              0.000000    7    0.1600   -12.441     1
# 2              0.913000    3    0.1010   -14.850     1
# 3              0.000028    5    0.3810    -9.316     1
# 4              0.000002    3    0.2290   -10.096     1
# ...                 ...  ...       ...       ...   ...
# 40429          0.000000    5    0.0916   -18.186     1
# 40430          0.000000    7    0.1630    -6.104     1
# 40431          0.000000   10    0.1030   -10.969     1
# 40432          0.959000    6    0.0995   -31.460     1
# 40433          0.925000    7    0.1130   -35.072     1
#
#                                                     name  popularity  \
# 0      Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1                                Clancy Lowered the Boom           5
# 2                                              Gati Bali           5
# 3                                              Danny Boy           3
# 4                            When Irish Eyes Are Smiling           2
# ...                                                  ...         ...
# 40429                                     Trying My Best          69
# 40430                          Christmas Isn't Christmas          55
# 40431                          Heather - Spotify Singles          64
# 40432                  We Contain Multitudes (from home)          70
# 40433                                    Med slutna ögon          70
#
#       release_date  speechiness    tempo         category
# 0             1921       0.0366   80.954  Relaxation/Yoga
# 1             1921       0.4150   60.936  Relaxation/Yoga
# 2             1921       0.0339  110.339  Relaxation/Yoga
# 3             1921       0.0354  100.109  Relaxation/Yoga
# 4             1921       0.0380  101.665  Relaxation/Yoga
# ...            ...          ...      ...              ...
# 40429   2020-05-08       0.0645   76.940  Relaxation/Yoga
# 40430   2020-11-20       0.0293   78.787  Relaxation/Yoga
# 40431   2020-11-11       0.0271   91.888  Relaxation/Yoga
# 40432   2020-08-26       0.0348   90.250  Relaxation/Yoga
# 40433   2020-02-21       0.0454   70.872  Relaxation/Yoga
#
# [40434 rows x 20 columns]

# %%
df_filtered.shape
# Out:
# (40434, 20)

# %%
df_filtered['category'].value_counts()
# Out:
# category
# Relaxation/Yoga    40180
# Devotional           254
# Name: count, dtype: int64

# %%
df_filtered['category'].unique()
# Out:
# array(['Relaxation/Yoga', 'Devotional'], dtype=object)

# %%
Relaxation_Yoga_df = df_filtered[df_filtered['category'] == "Relaxation/Yoga"]
Relaxation_Yoga_df
# Out:
#        valence  year  acousticness  \
# 0       0.0594  1921         0.982
# 1       0.9630  1921         0.732
# 2       0.0394  1921         0.961
# 3       0.1650  1921         0.967
# 4       0.2530  1921         0.957
# ...        ...   ...           ...
# 40429   0.3520  2020         0.951
# 40430   0.3620  2020         0.719
# 40431   0.3520  2020         0.886
# 40432   0.1690  2020         0.994
# 40433   0.0838  2020         0.974
#
#                                                  artists  danceability  \
# 0      ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                         ['Dennis Day']         0.819
# 2      ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                       ['Frank Parker']         0.275
# 4                                         ['Phil Regan']         0.418
# ...                                                  ...           ...
# 40429                                   ['Anson Seabra']         0.691
# 40430                                     ['Dan + Shay']         0.420
# 40431                                     ['Tate McRae']         0.569
# 40432                                 ['Ólafur Arnalds']         0.281
# 40433                                   ['Najma Wallin']         0.175
#
#        duration_ms   energy  explicit                      id  \
# 0           831667  0.21100         0  4BJqT0PrAfrxzMOxytFOIz
# 1           180533  0.34100         0  7xPhfUan2yNtyFG0cUWkt8
# 2           500062  0.16600         0  1o6I8BglA6ylDMrIELygv1
# 3           210000  0.30900         0  3ftBPsC5vPBKxYSee08FDH
# 4           166693  0.19300         0  4d6HGyGT8e121BsdKmw9v6
# ...            ...      ...       ...                     ...
# 40429       222468  0.06820         0  6hjh2phISvfR1Ib6S0FK7b
# 40430       195067  0.46600         0  6DeGFcrDiYDuyV7e7KnqPd
# 40431       190652  0.27100         0  2GSLoT7abyYGchSSDCpWEI
# 40432       190500  0.03330         0  13MOQ6oQqkrZEDkZOHukCw
# 40433       133500  0.00759         0  6RuFOroO9VO0aMGEzirLHk
#
#        instrumentalness  key  liveness  loudness  mode  \
# 0              0.878000   10    0.6650   -20.096     1
# 1              0.000000    7    0.1600   -12.441     1
# 2              0.913000    3    0.1010   -14.850     1
# 3              0.000028    5    0.3810    -9.316     1
# 4              0.000002    3    0.2290   -10.096     1
# ...                 ...  ...       ...       ...   ...
# 40429          0.000000    5    0.0916   -18.186     1
# 40430          0.000000    7    0.1630    -6.104     1
# 40431          0.000000   10    0.1030   -10.969     1
# 40432          0.959000    6    0.0995   -31.460     1
# 40433          0.925000    7    0.1130   -35.072     1
#
#                                                     name  popularity  \
# 0      Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1                                Clancy Lowered the Boom           5
# 2                                              Gati Bali           5
# 3                                              Danny Boy           3
# 4                            When Irish Eyes Are Smiling           2
# ...                                                  ...         ...
# 40429                                     Trying My Best          69
# 40430                          Christmas Isn't Christmas          55
# 40431                          Heather - Spotify Singles          64
# 40432                  We Contain Multitudes (from home)          70
# 40433                                    Med slutna ögon          70
#
#       release_date  speechiness    tempo         category
# 0             1921       0.0366   80.954  Relaxation/Yoga
# 1             1921       0.4150   60.936  Relaxation/Yoga
# 2             1921       0.0339  110.339  Relaxation/Yoga
# 3             1921       0.0354  100.109  Relaxation/Yoga
# 4             1921       0.0380  101.665  Relaxation/Yoga
# ...            ...          ...      ...              ...
# 40429   2020-05-08       0.0645   76.940  Relaxation/Yoga
# 40430   2020-11-20       0.0293   78.787  Relaxation/Yoga
# 40431   2020-11-11       0.0271   91.888  Relaxation/Yoga
# 40432   2020-08-26       0.0348   90.250  Relaxation/Yoga
# 40433   2020-02-21       0.0454   70.872  Relaxation/Yoga
#
# [40180 rows x 20 columns]

# %%
devotional_df = df_filtered[df_filtered['category'] == "Devotional"]
devotional_df
# Out:
#        valence  year  acousticness  \
# 99       0.127  1922       0.67400
# 102      0.402  1922       0.52100
# 221      0.599  1923       0.99600
# 330      0.759  1924       0.99000
# 424      0.315  1925       0.99300
# ...        ...   ...           ...
# 38449    0.606  1956       0.82900
# 39728    0.467  1983       0.99300
# 39768    0.247  1984       0.00441
# 40140    0.447  2003       0.03550
# 40393    0.169  2018       0.94400
#
#                                                  artists  danceability  \
# 99                                               ['Uli']         0.645
# 102                                              ['Uli']         0.298
# 221                                  ['Ignacio Corsini']         0.493
# 330                                  ['Ignacio Corsini']         0.461
# 424                                 ['Francisco Canaro']         0.443
# ...                                                  ...           ...
# 38449  ['Wolfgang Amadeus Mozart', 'Wiener Philharmon...         0.397
# 39728                                ['Daniel Johnston']         0.579
# 39768                                      ['Hüsker Dü']         0.164
# 40140                              ['The White Stripes']         0.191
# 40393                                     ['Womb Sound']         0.284
#
#        duration_ms  energy  explicit                      id  \
# 99          126903   0.445         0  35iwgR4jXetI318WEWsa1Q
# 102         157333   0.460         0  0PH9AACae1f957JAavhOl2
# 221         150640   0.109         0  282GBb96Uc1l3nvDZU14Wr
# 330          97493   0.587         0  5IO4UbhRB6NKME2WHUgHN1
# 424         171533   0.265         0  2HHvjG9sSrs5uVeity8AvB
# ...            ...     ...       ...                     ...
# 38449       251733   0.406         0  6xXeL1zUfOTZrwyOx1N01g
# 39728       282280   0.391         0  2ICmO7SNL85kTurb3o5fd6
# 39768       100800   0.844         0  1dP2CDIpuuRxJxiZyzD4is
# 40140       108400   0.990         0  52vZfFJ4ZKLDabaTAH242l
# 40393       137183   0.501         0  6DCxsitO66sRaPLAZJMFkT
#
#        instrumentalness  key  liveness  loudness  mode  \
# 99                0.744    0    0.1510   -13.338     1
# 102               0.856    1    0.4360   -18.645     1
# 221               0.822    2    0.4000   -23.485     0
# 330               0.973    0    0.6830   -18.780     1
# 424               0.959    1    0.1410   -17.091     1
# ...                 ...  ...       ...       ...   ...
# 38449             0.739    7    0.9350   -19.721     0
# 39728             0.877    0    0.1050   -13.865     1
# 39768             0.713    9    0.2340   -16.252     1
# 40140             0.575    9    0.0679    -4.086     1
# 40393             0.691   10    0.1080   -32.431     0
#
#                                                     name  popularity  \
# 99                                                 Carve           6
# 102                                             Lazy Boi           0
# 221                       La Garconniere - Remasterizado           0
# 330                            Maullidos - Remasterizado           0
# 424                 Virgencita del Talar - Remasterizado           0
# ...                                                  ...         ...
# 38449  Symphony No. 25 in G Minor, K. 183: IV. Allegr...           7
# 39728                         No More Pushing Joe Around          23
# 39768                                 Dreams Reoccurring          25
# 40140                                          Hypnotize          41
# 40393  Womb Sound With Mother's Heartbeat and Sleep P...          67
#
#       release_date  speechiness    tempo    category
# 99      1922-02-22        0.451  104.851  Devotional
# 102     1922-02-22        0.453   87.921  Devotional
# 221     1923-03-29        0.423  120.344  Devotional
# 330     1924-03-29        0.490   67.355  Devotional
# 424     1925-07-12        0.460   69.038  Devotional
# ...            ...          ...      ...         ...
# 38449   1956-01-01        0.447  117.452  Devotional
# 39728   1983-09-01        0.650   64.927  Devotional
# 39768   1984-01-01        0.605  196.847  Devotional
# 40140   2003-04-01        0.530  184.103  Devotional
# 40393   2018-09-18        0.439   68.631  Devotional
#
# [254 rows x 20 columns]

# %% [markdown]
# # EDA (Exploratory data analysis)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="category", data=df_filtered)
plt.title("Count of Tracks by Category")
plt.xlabel("Category")
plt.ylabel("Number of Tracks")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["tempo"], kde=True, bins=30, color="blue")
plt.title("Distribution of Tempo")
plt.xlabel("Tempo")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["energy"], kde=True, bins=30, color="green")
plt.title("Distribution of Energy")
plt.xlabel("Energy")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["danceability"], kde=True, bins=30, color="lightblue")
plt.title("Distribution of Danceability")
plt.xlabel("danceability")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["acousticness"], kde=True, bins=30, color="green")
plt.title("Distribution of Acousticness")
plt.xlabel("acousticness")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["valence"], kde=True, bins=30, color="black")
plt.title("Distribution of Valence")
plt.xlabel("Valence")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["liveness"], kde=True, bins=30, color="red")
plt.title("Distribution of Liveness")
plt.xlabel("liveness")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["speechiness"], kde=True, bins=30, color="purple")
plt.title("Distribution of Speechiness")
plt.xlabel("speechiness")
plt.ylabel("Count")
plt.show()

# %%
# Compute correlation matrix
correlation_matrix = df[["tempo", "energy", "danceability", "acousticness", "valence", "liveness", "speechiness"]].corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# High Acousticness (-0.75 with Energy, -0.27 with Danceability)
# Low Energy (Negatively Correlated with Acousticness)
# Low Tempo (-0.21 correlation with Acousticness)
# Moderate Valence (Happiness or Positivity)

# %%
# Features to compare
features_to_compare = ["energy", "tempo", "valence", "danceability", "acousticness"]

# Set up subplots
fig, axes = plt.subplots(nrows=len(features_to_compare), ncols=1, figsize=(10, 15))
N
# Create boxplots
for i, feature in enumerate(features_to_compare):
    sns.boxplot(x="category", y=feature, data=df_filtered, ax=axes[i])
    axes[i].set_title(f"{feature.capitalize()} Across Categories")
n
plt.tight_layout()
plt.show()

# Relaxation/Yoga music is low-energy, slow, acoustic, and moderately happy, making it ideal for meditation.

# Devotional music has more variety—some songs are uplifting, faster, and slightly more energetic, though still mostly acoustic.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_filtered, x="energy", y="danceability", hue="category", alpha=0.7, palette="coolwarm")
plt.title("Energy vs Danceability")
plt.xlabel("Energy")
plt.ylabel("Danceability")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_filtered, x="tempo", y="valence", hue="category", alpha=0.7, palette="viridis")
plt.title("Tempo vs. Valence (Happiness Level)")
plt.xlabel("Tempo (BPM)")
plt.ylabel("Valence (Happiness)")
plt.show()

# %%
# Get category counts
category_counts = df_filtered["category"].value_counts()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct="%1.1f%%", colors=["blue", "green", "orange"])
plt.title("Category Distribution of Songs")
plt.show()

# %% [markdown]
# # Model Implementation

# %%
# Select numerical features for standardization
numerical_features = ["valence", "danceability", "energy", "tempo", "acousticness", "liveness", "speechiness", "instrumentalness"]

# Appllying StandardScaler
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_filtered[numerical_features]), columns=numerical_features)

# %%
df_scaled
# Out:
#         valence  danceability    energy     tempo  acousticness  liveness  \
# 0     -1.345371     -1.016140 -0.050809 -0.695201      0.776182  3.035181
# 1      2.157355      2.008621  0.980878 -1.935559     -2.166848 -0.224676
# 2     -1.422899     -0.741671 -0.407931  1.125555      0.528967 -0.605531
# 3     -0.936021     -1.038546  0.726924  0.491683      0.599600  1.201915
# 4     -0.594897     -0.237544 -0.193658  0.588096      0.481879  0.220730
# ...         ...           ...       ...       ...           ...       ...
# 40429 -0.211132      1.291640 -1.184078 -0.943917      0.411246 -0.666209
# 40430 -0.172368     -0.226342  1.972885 -0.829473     -2.319885 -0.205310
# 40431 -0.211132      0.608268  0.425354 -0.017708     -0.353942 -0.592620
# 40432 -0.920516     -1.004938 -1.461046 -0.119201      0.917447 -0.615213
# 40433 -1.250786     -1.598687 -1.665082 -1.319903      0.682005 -0.528069
#
#        speechiness  instrumentalness
# 0        -0.318823          1.437464
# 1         2.203225         -0.810898
# 2        -0.336818          1.527091
# 3        -0.326821         -0.810827
# 4        -0.309492         -0.810894
# ...            ...               ...
# 40429    -0.132868         -0.810898
# 40430    -0.367477         -0.810898
# 40431    -0.382140         -0.810898
# 40432    -0.330820          1.644887
# 40433    -0.260170          1.557821
#
# [40434 rows x 8 columns]

# %%
# Initializing Nearest Neighbors model
neigh = NearestNeighbors(n_neighbors=6, metric='cosine')  # 6 includes the input song
neigh.fit(df_scaled)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=6)

# %%
def get_recommendations(song_name, num_recommendations=5):
    song_idx = df_filtered[df_filtered["name"] == song_name].index

    if len(song_idx) == 0:
        print(f"Song '{song_name}' not found in the dataset.")
        return None

    song_idx = song_idx[0]
    
    song_features = df_scaled.iloc[song_idx].values.reshape(1, -1)

    distances, indices = neigh.kneighbors(song_features)

    recommended_indices = indices[0][1:num_recommendations+1]

    recommendations = df_filtered.iloc[recommended_indices][["name", "artists", "category"]]
    recommendations["similarity"] = 1 - distances[0][1:num_recommendations+1]

    return recommendations

# %%
if __name__ == "__main__":
    while True:
        user_input = input("\nEnter a song name for recommendations (or type 'exit' to quit): ").strip()

        if user_input.lower() == 'exit':
            print("Exiting recommendation system.")
            break

        recommendations = get_recommendations(user_input)

        if recommendations is not None:
            print("\nRecommended Songs:")
            print(recommendations)
        break
# Out:
# Enter a song name for recommendations (or type 'exit' to quit):  No More Pushing Joe Around
# Recommended Songs:
#                                                    name  \
# 26806                             Dachma Sar Nalashkene
# 424                Virgencita del Talar - Remasterizado
# 5064                      Canta Corazón - Remasterizado
# 12036  Bongili Work Song (Girls' Chorus, Pestle Sounds)
# 24374                      Raja Titha Tovar Ubha Asnaar
#
#                                            artists    category  similarity
# 26806                               ['Mala Karim']  Devotional    0.966729
# 424                           ['Francisco Canaro']  Devotional    0.936928
# 5064       ['Francisco Canaro', 'Azucena Maizani']  Devotional    0.936595
# 12036  ['Young Bongili women beating out bananas']  Devotional    0.925672
# 24374                              ['Amar Sheikh']  Devotional    0.920519
# C:\Users\rajee\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
df_filtered
# Out:
#        valence  year  acousticness  \
# 0       0.0594  1921         0.982
# 1       0.9630  1921         0.732
# 2       0.0394  1921         0.961
# 3       0.1650  1921         0.967
# 4       0.2530  1921         0.957
# ...        ...   ...           ...
# 40429   0.3520  2020         0.951
# 40430   0.3620  2020         0.719
# 40431   0.3520  2020         0.886
# 40432   0.1690  2020         0.994
# 40433   0.0838  2020         0.974
#
#                                                  artists  danceability  \
# 0      ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                         ['Dennis Day']         0.819
# 2      ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                       ['Frank Parker']         0.275
# 4                                         ['Phil Regan']         0.418
# ...                                                  ...           ...
# 40429                                   ['Anson Seabra']         0.691
# 40430                                     ['Dan + Shay']         0.420
# 40431                                     ['Tate McRae']         0.569
# 40432                                 ['Ólafur Arnalds']         0.281
# 40433                                   ['Najma Wallin']         0.175
#
#        duration_ms   energy  explicit                      id  \
# 0           831667  0.21100         0  4BJqT0PrAfrxzMOxytFOIz
# 1           180533  0.34100         0  7xPhfUan2yNtyFG0cUWkt8
# 2           500062  0.16600         0  1o6I8BglA6ylDMrIELygv1
# 3           210000  0.30900         0  3ftBPsC5vPBKxYSee08FDH
# 4           166693  0.19300         0  4d6HGyGT8e121BsdKmw9v6
# ...            ...      ...       ...                     ...
# 40429       222468  0.06820         0  6hjh2phISvfR1Ib6S0FK7b
# 40430       195067  0.46600         0  6DeGFcrDiYDuyV7e7KnqPd
# 40431       190652  0.27100         0  2GSLoT7abyYGchSSDCpWEI
# 40432       190500  0.03330         0  13MOQ6oQqkrZEDkZOHukCw
# 40433       133500  0.00759         0  6RuFOroO9VO0aMGEzirLHk
#
#        instrumentalness  key  liveness  loudness  mode  \
# 0              0.878000   10    0.6650   -20.096     1
# 1              0.000000    7    0.1600   -12.441     1
# 2              0.913000    3    0.1010   -14.850     1
# 3              0.000028    5    0.3810    -9.316     1
# 4              0.000002    3    0.2290   -10.096     1
# ...                 ...  ...       ...       ...   ...
# 40429          0.000000    5    0.0916   -18.186     1
# 40430          0.000000    7    0.1630    -6.104     1
# 40431          0.000000   10    0.1030   -10.969     1
# 40432          0.959000    6    0.0995   -31.460     1
# 40433          0.925000    7    0.1130   -35.072     1
#
#                                                     name  popularity  \
# 0      Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1                                Clancy Lowered the Boom           5
# 2                                              Gati Bali           5
# 3                                              Danny Boy           3
# 4                            When Irish Eyes Are Smiling           2
# ...                                                  ...         ...
# 40429                                     Trying My Best          69
# 40430                          Christmas Isn't Christmas          55
# 40431                          Heather - Spotify Singles          64
# 40432                  We Contain Multitudes (from home)          70
# 40433                                    Med slutna ögon          70
#
#       release_date  speechiness    tempo         category
# 0             1921       0.0366   80.954  Relaxation/Yoga
# 1             1921       0.4150   60.936  Relaxation/Yoga
# 2             1921       0.0339  110.339  Relaxation/Yoga
# 3             1921       0.0354  100.109  Relaxation/Yoga
# 4             1921       0.0380  101.665  Relaxation/Yoga
# ...            ...          ...      ...              ...
# 40429   2020-05-08       0.0645   76.940  Relaxation/Yoga
# 40430   2020-11-20       0.0293   78.787  Relaxation/Yoga
# 40431   2020-11-11       0.0271   91.888  Relaxation/Yoga
# 40432   2020-08-26       0.0348   90.250  Relaxation/Yoga
# 40433   2020-02-21       0.0454   70.872  Relaxation/Yoga
#
# [40434 rows x 20 columns]

# %%
print(df_filtered["name"].sample(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df_filtered["name"].sample(10))
#
# NameError: name 'df_filtered' is not defined
