# %%
from sklearn.ensemble import IsolationForest
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data_encoded=sns.load_dataset('iris')
data_encoded
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14420\3478702981.py in ?()
#       1 clf = IsolationForest(random_state=10,contamination=.01)
# ----> 2 clf.fit(data_encoded)
#
# C:\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# C:\Python312\Lib\site-packages\sklearn\ensemble\_iforest.py in ?(self, X, y, sample_weight)
#     313         -------
#     314         self : object
#     315             Fitted estimator.
#     316         """
# --> 317         X = validate_data(
# ...
